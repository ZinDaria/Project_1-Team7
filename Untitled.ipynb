# %%
# %matplotlib notebook

# %%
# Import Dependencies

import pandas as pd
from matplotlib import pyplot as plt
from scipy import stats
import numpy as np

# %%
# Load credit card data set into pandas
credit_card_df =pd.read_csv("Resources/cleaned_data.csv")

credit_card_df.head()
# Out:
#    Transaction ID        Date Day of Week  Time Type of Card Entry Mode  \
# 0         3577209  2020-10-14   Wednesday    19         Visa        Tap
# 1         3039221  2020-10-14   Wednesday    17   MasterCard        PIN
# 2         2694780  2020-10-14   Wednesday    14         Visa        Tap
# 3         2640960  2020-10-13     Tuesday    14         Visa        Tap
# 4         2771031  2020-10-13     Tuesday    23         Visa        CVC
#
#    Amount (in £) Type of Transaction Merchant Group Country of Transaction  \
# 0            5.0                 POS  Entertainment         United Kingdom
# 1          288.0                 POS       Services                    USA
# 2            5.0                 POS     Restaurant                  India
# 3           28.0                 POS  Entertainment         United Kingdom
# 4           91.0              Online    Electronics                    USA
#
#   Shipping Address Country of Residence Gender  Age      Bank  Fraud
# ...

# %%
total_transactions = 99977
fraud_transactions = 7192
# non_fraud_transactions = total_transactions - fraud_transactions
non_fraud_transactions = 92785

# % of fraudulent transactions to total transactions:
percent_fraud = round(((fraud_transactions/total_transactions)* 100), 2)
print(f"The percentage of fraud transactions is {percent_fraud}%")
# Out:
# The percentage of fraud transactions is 7.19%

# %%
non_fraud_df = credit_card_df.loc[credit_card_df["Fraud"] == 0]
non_fraud_df
# Out:
#        Transaction ID        Date Day of Week  Time Type of Card Entry Mode  \
# 0             3577209  2020-10-14   Wednesday    19         Visa        Tap
# 1             3039221  2020-10-14   Wednesday    17   MasterCard        PIN
# 2             2694780  2020-10-14   Wednesday    14         Visa        Tap
# 3             2640960  2020-10-13     Tuesday    14         Visa        Tap
# 5             3446698  2020-10-13     Tuesday    20   MasterCard        Tap
# ...               ...         ...         ...   ...          ...        ...
# 99972         3203892  2020-10-13     Tuesday    22   MasterCard        Tap
# 99973         3304849  2020-10-14   Wednesday    23   MasterCard        PIN
# 99974         3532129  2020-10-13     Tuesday    11   MasterCard        PIN
# 99975         3107092  2020-10-14   Wednesday    22         Visa        Tap
# 99976         3400711  2020-10-14   Wednesday    16         Visa        PIN
#
# ...

# %%
grouped_bank = non_fraud_df.groupby('Bank')
grouped_bank[["Amount (in £)", "Fraud"]].sum()
# Out:
#           Amount (in £)  Fraud
# Bank
# Barclays      4351304.0      0
# HSBC          1058908.0      0
# Halifax       1070057.0      0
# Lloyds        1061739.0      0
# Metro         1088651.0      0
# Monzo         1069950.0      0
# RBS           1095300.0      0

# %%
grouped_bank = non_fraud_df.groupby('Bank')
grouped_bank[["Amount (in £)", "Fraud"]].count()
# Out:
#           Amount (in £)  Fraud
# Bank
# Barclays          36935  36935
# HSBC               9301   9301
# Halifax            9306   9306
# Lloyds             9270   9270
# Metro              9206   9206
# Monzo              9374   9374
# RBS                9393   9393

# %%
fraud_df = credit_card_df.loc[credit_card_df["Fraud"] == 1]
fraud_df
# Out:
#        Transaction ID        Date Day of Week  Time Type of Card Entry Mode  \
# 4             2771031  2020-10-13     Tuesday    23         Visa        CVC
# 11            3474192  2020-10-14   Wednesday     1   MasterCard        PIN
# 16            3513029  2020-10-13     Tuesday     0   MasterCard        CVC
# 37            3316175  2020-10-14   Wednesday     3   MasterCard        PIN
# 42            2617497  2020-10-14   Wednesday     4         Visa        PIN
# ...               ...         ...         ...   ...          ...        ...
# 99926         3602464  2020-10-14   Wednesday     1   MasterCard        PIN
# 99931         3257939  2020-10-13     Tuesday    12   MasterCard        CVC
# 99946         3249369  2020-10-13     Tuesday    18         Visa        PIN
# 99951         2596607  2020-10-13     Tuesday     9   MasterCard        CVC
# 99970         2816417  2020-10-13     Tuesday    17         Visa        Tap
#
# ...

# %%
grouped_bank = fraud_df.groupby('Bank')
grouped_bank[["Amount (in £)", "Fraud"]].sum()
# Out:
#           Amount (in £)  Fraud
# Bank
# Barclays       189835.0   2983
# HSBC            40477.0    653
# Halifax         42124.0    678
# Lloyds          39807.0    693
# Metro           59191.0    805
# Monzo           48126.0    728
# RBS             39935.0    652

# %%
grouped_bank = credit_card_df.groupby('Bank')
grouped_bank["Amount (in £)"].sum()
# Out:
# Bank
# Barclays    4541139.0
# HSBC        1099385.0
# Halifax     1112181.0
# Lloyds      1101546.0
# Metro       1147842.0
# Monzo       1118076.0
# RBS         1135235.0
# Name: Amount (in £), dtype: float64

# %%
plt.figure(figsize=(10,6))
plt.bar(df.State,df.Inches, alpha=0.5, align="edge")

x_axis = credit_card_df["Time"]
y_axis = credit_card_df["Fraud"]

plt.bar(x_axis, rain_df["Inches"], color='r', alpha=0.5, align="edge")
plt.xticks(tick_locations, rain_df["State"], rotation="vertical")

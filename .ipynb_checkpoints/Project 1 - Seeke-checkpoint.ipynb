# %% [markdown]
# # Credit Card Fraud Detection
#
# The dataset used contains data about credit card transctions that occured on two days, Tuesday October 13 and Wednesday October 14 2020.
#
# ## Part 1 - Read and Pre-process Data

# %%
# Import Dependencies
import pandas as pd
import numpy as numpy
import matplotlib.pyplot as plt
import scipy.stats as st

# %%
# Read CSV file
data_df = pd.read_csv("Resources/CreditCardData.csv")
data_df.head()
# Out:
#   Transaction ID       Date Day of Week  Time Type of Card Entry Mode Amount  \
# 0      #3577 209  14-Oct-20   Wednesday    19         Visa        Tap     £5
# 1      #3039 221  14-Oct-20   Wednesday    17   MasterCard        PIN   £288
# 2      #2694 780  14-Oct-20   Wednesday    14         Visa        Tap     £5
# 3      #2640 960  13-Oct-20     Tuesday    14         Visa        Tap    £28
# 4      #2771 031  13-Oct-20     Tuesday    23         Visa        CVC    £91
#
#   Type of Transaction Merchant Group Country of Transaction Shipping Address  \
# 0                 POS  Entertainment         United Kingdom   United Kingdom
# 1                 POS       Services                    USA              USA
# 2                 POS     Restaurant                  India            India
# 3                 POS  Entertainment         United Kingdom            India
# 4              Online    Electronics                    USA              USA
#
#   Country of Residence Gender   Age      Bank  Fraud
# 0       United Kingdom      M  25.2       RBS      0
# 1                  USA      F  49.6    Lloyds      0
# 2                India      F  42.2  Barclays      0
# 3       United Kingdom      F  51.0  Barclays      0
# 4       United Kingdom      M  38.0   Halifax      1

# %%
# Check number of rows and columns
data_df.shape
# Out:
# (100000, 16)

# %%
data_df.columns
# Out:
# Index(['Transaction ID', 'Date', 'Day of Week', 'Time', 'Type of Card',
#        'Entry Mode', 'Amount', 'Type of Transaction', 'Merchant Group',
#        'Country of Transaction', 'Shipping Address', 'Country of Residence',
#        'Gender', 'Age', 'Bank', 'Fraud'],
#       dtype='object')

# %%
# Delete date column
del data_df["Date"]
del data_df["Day of Week"]
data_df.head(2)
# Out:
#   Transaction ID  Time Type of Card Entry Mode Amount Type of Transaction  \
# 0      #3577 209    19         Visa        Tap     £5                 POS
# 1      #3039 221    17   MasterCard        PIN   £288                 POS
#
#   Merchant Group Country of Transaction Shipping Address Country of Residence  \
# 0  Entertainment         United Kingdom   United Kingdom       United Kingdom
# 1       Services                    USA              USA                  USA
#
#   Gender   Age    Bank  Fraud
# 0      M  25.2     RBS      0
# 1      F  49.6  Lloyds      0

# %%
# Identify incomplete rows
data_df.count()
# Out:
# Transaction ID            100000
# Time                      100000
# Type of Card              100000
# Entry Mode                100000
# Amount                     99994
# Type of Transaction       100000
# Merchant Group             99990
# Country of Transaction    100000
# Shipping Address           99995
# Country of Residence      100000
# Gender                     99996
# Age                       100000
# Bank                      100000
# Fraud                     100000
# dtype: int64

# %%
# Since there are only few rows with incomplete information, drop rows with missing data
data_df = data_df.dropna(how="any")

# %%
# Verify dropped rows
data_df.count()
# Out:
# Transaction ID            99977
# Time                      99977
# Type of Card              99977
# Entry Mode                99977
# Amount                    99977
# Type of Transaction       99977
# Merchant Group            99977
# Country of Transaction    99977
# Shipping Address          99977
# Country of Residence      99977
# Gender                    99977
# Age                       99977
# Bank                      99977
# Fraud                     99977
# dtype: int64

# %%
# Check data types of each column
data_df.dtypes
# Out:
# Transaction ID             object
# Time                        int64
# Type of Card               object
# Entry Mode                 object
# Amount                     object
# Type of Transaction        object
# Merchant Group             object
# Country of Transaction     object
# Shipping Address           object
# Country of Residence       object
# Gender                     object
# Age                       float64
# Bank                       object
# Fraud                       int64
# dtype: object

# %%
# Change the data type for Amount into the appropriate type
data_df["Amount"] = data_df["Amount"].str.replace('£', '')
data_df["Amount"] = data_df["Amount"].astype("float64")
data_df.head(2)
# Out:
#   Transaction ID  Time Type of Card Entry Mode  Amount Type of Transaction  \
# 0      #3577 209    19         Visa        Tap     5.0                 POS
# 1      #3039 221    17   MasterCard        PIN   288.0                 POS
#
#   Merchant Group Country of Transaction Shipping Address Country of Residence  \
# 0  Entertainment         United Kingdom   United Kingdom       United Kingdom
# 1       Services                    USA              USA                  USA
#
#   Gender   Age    Bank  Fraud
# 0      M  25.2     RBS      0
# 1      F  49.6  Lloyds      0

# %%
# Verify that data types have been converted
data_df.dtypes
# Out:
# Transaction ID             object
# Time                        int64
# Type of Card               object
# Entry Mode                 object
# Amount                    float64
# Type of Transaction        object
# Merchant Group             object
# Country of Transaction     object
# Shipping Address           object
# Country of Residence       object
# Gender                     object
# Age                       float64
# Bank                       object
# Fraud                       int64
# dtype: object

# %%
# Reset index
data_df = data_df.reset_index(drop=True)
data_df.head(2)
# Out:
#   Transaction ID  Time Type of Card Entry Mode  Amount Type of Transaction  \
# 0      #3577 209    19         Visa        Tap     5.0                 POS
# 1      #3039 221    17   MasterCard        PIN   288.0                 POS
#
#   Merchant Group Country of Transaction Shipping Address Country of Residence  \
# 0  Entertainment         United Kingdom   United Kingdom       United Kingdom
# 1       Services                    USA              USA                  USA
#
#   Gender   Age    Bank  Fraud
# 0      M  25.2     RBS      0
# 1      F  49.6  Lloyds      0

# %%
# Display a statistical overview of the numerical columns
data_df.describe()
# Out:
#                Time        Amount           Age         Fraud
# count  99977.000000  99977.000000  99977.000000  99977.000000
# mean      14.563100    112.579933     44.993595      0.071937
# std        5.308202    123.435613      9.948121      0.258384
# min        0.000000      5.000000     15.000000      0.000000
# 25%       10.000000     17.000000     38.200000      0.000000
# 50%       15.000000     30.000000     44.900000      0.000000
# 75%       19.000000    208.000000     51.700000      0.000000
# max       24.000000    400.000000     86.100000      1.000000

# %%
# Rename Amount column
data_df = data_df.rename(columns={"Amount": "Amount (in £)"})
data_df.tail(2)
# Out:
#       Transaction ID  Time Type of Card Entry Mode  Amount (in £)  \
# 99975      #3107 092    22         Visa        Tap           25.0
# 99976      #3400 711    16         Visa        PIN          226.0
#
#       Type of Transaction Merchant Group Country of Transaction  \
# 99975                 POS       Products         United Kingdom
# 99976                 POS     Restaurant         United Kingdom
#
#       Shipping Address Country of Residence Gender   Age      Bank  Fraud
# 99975   United Kingdom       United Kingdom      M  48.2  Barclays      0
# 99976   United Kingdom       United Kingdom      M  31.7     Monzo      0

# %%
data_df["Transaction ID	"] = data_df["Transaction ID"].str.replace('[#', '')
data_df["Amount"] = data_df["Amount"].astype("float64")
data_df.head(2)
